# %% [markdown]
# # Lab 13
#
# ## Instructions
#
# Open the file in Jupyter Lab. Fill out the problems and submit the completed notebook on Laulima.
#
# ## Hawaii Campaigns Contribution Data
#
# For this lab, you will be working with the Hawaii Campaigns Contribution data from November 2006 to June 2019. The data is loaded for you as `data`. Make sure to run the below cell to ensure the data is loaded.

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 5)
data = pd.read_csv('Campaign_Contributions_Received_By_Hawaii_State_and_County_Candidates_From_November_8__2006_Through_June_30__2019.csv')
data
# Out:
#              Candidate Name        Contributor Type        Contributor Name  \
# 0           Abbett, Richard               Candidate      Abbett, Richard E.
# 1           Abbett, Richard               Candidate      Abbett, Richard E.
# 2           Abbett, Richard               Candidate      Abbett, Richard E.
# 3              Abe, Michael              Individual        Kanehe, Sally L.
# 4              Abe, Michael  Noncandidate Committee   Hawaii Optometric PAC
# ...                     ...                     ...                     ...
# 159308       Zahnd, Laurent               Candidate       Zahnd, Laurent R.
# 159309  Zibakalam, Emmanuel              Individual      Strona, Jeffrey K.
# 159310  Zibakalam, Emmanuel               Candidate  Zibakalam, Emmanuel F.
# 159311  Zibakalam, Emmanuel               Candidate  Zibakalam, Emmanuel F.
# 159312  Zibakalam, Emmanuel               Candidate  Zibakalam, Emmanuel F.
#
#               Date  Amount  Aggregate Employer  \
# ...

# %% [markdown]
# ## Problem 1: Candidates/Contributors with the highest total amount donated
#
# Find the candidates with the highest total amount donated. Use the `Amount` column to determine this. Use a bar chart to plot out the top 5.

# %%
# Insert solution here

# %% [markdown]
# ## Problem 2: Contributors with the highest total amount donated
#
# Again, find the highest total amount donated, but use the contributor's name.

# %%
# Insert solution here

# %% [markdown]
# ## Problem 3: Neil Abercrombie's Donations
#
# Select rows for Neil Abercrombie when he was running for the office of Governor.
#
# * How much money was donated from out of state vs in state?
# * How much money was donated during each election period?

# %%
# Insert solution here

# %% [markdown]
# ## Problem 4: Tommy Waters vs. Trevor Ozawa
#
# Select rows for each of these candidates.
#
# * Who got the most money for each election period?
# * Who had the most donors in state?

# %%
# Insert solution here

# %% [markdown]
# ## Problem 5: Analyze a race in ending in 2012.
#
# Do an analysis on a race between 2 or more candidates (must be same district or same office and county) in the election period ending with 2012. A data frame for all races has been provided below.
#
# * Use a bar chart to compare how much money was donated to candidates.
# * Out of the total, how much money was contributed by a candidate?

# %%
# Insert solution here
ending_in_2012 = data[data['Election Period'].str.endswith('2012')]
ending_in_2012
# Out:
#            Candidate Name Contributor Type  \
# 5         Yukimura, JoAnn       Individual
# 19      Abercrombie, Neil       Individual
# 24      Abercrombie, Neil       Individual
# 32      Abercrombie, Neil       Individual
# 39      Abercrombie, Neil     Other Entity
# ...                   ...              ...
# 159285    Yukimura, JoAnn       Individual
# 159288    Yukimura, JoAnn       Individual
# 159289    Yukimura, JoAnn       Individual
# 159293    Yukimura, JoAnn       Individual
# 159304    Yukimura, JoAnn       Individual
#
#                                Contributor Name        Date  Amount  \
# 5                            SHIRAISHI, SHERMAN  07/03/2012    50.0
# 19                         Blaylock, Frazier W.  12/09/2010   250.0
# 24                                Wine, Joel M.  06/29/2012   400.0
# 32                                Wine, Joel M.  06/29/2012   800.0
# 39      Dow Chemical Agricultural Executive PAC  11/07/2011   600.0
# ...

# %% [markdown]
# ## Extra Credit: Comparing money earned with voting results (5 extra points)
#
# The voting results for the 2012 election can be found at: https://data.hawaii.gov/Government-Wide-Support/General-Election-2012-Results/eze4-hq7j
#
# Using your race in problem 5, find the total number of votes that each candidate received. What is the cost per vote for each candidate?

# %%
# Insert solution here
